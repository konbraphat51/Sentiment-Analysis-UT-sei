# %% [markdown]
# # 時期ごとの極性・共起変遷を追う

# %%
ID = "UT-sei"

POPULATION_ID = "population"

PERIOD_ID = "year"

#分析対象の単語ファイル
keywords_file = "Keywords/Timelapse/%s-from-%s.txt"%(ID, POPULATION_ID)

#ストップワード抜きの形態素解析・極性分析完了したデータ
without_stopwords_text_file = "Progresses/NonStopword/%s-from-%s.txt"%(ID, POPULATION_ID)

##TFIDFモデル
tfidf_model_file = "Models/Tfidf/%s-from-%s.model"%(ID, POPULATION_ID)

#保存するファイル
sentiment_timelapse_file = "Sentiment/Timelapse/%s-from-%s-by-%s.txt"%(ID, POPULATION_ID, PERIOD_ID)

#内部的に品詞を区別する区切り文字
TOKEN_DIVIDER = "<334>"

# %%
#共起キーワードのストップワード（ここだけ）
local_stopwords = ["東大生", "br", "東大", "無い"]

# %% [markdown]
# ##

# %% [markdown]
# ## 与えられた時期にインデックスを割り振る
# 分けたい時期にあわせて書き換える

# %%
from datetime import datetime

# %%
#これを書き換える
#万が一 -1 が出てしまうとエラーが出てしまうので注意（上限はない）
def get_time_index(time: datetime):
    #2000年から一年ごとに割り振る
    if time == None:
        return None

    years_passed = time.year - 2000
    
    if years_passed >= 0:
        return years_passed
    else:
        return 0

#保持しているデータの形式からdatetime型に変換
def convert_time(text: str):
    if (text == None) | (text == "None"):
        return None
    else:
        return datetime.strptime(text, "%Y/%m/%d|%H/%M/%S")

#最大インデックスを算出
MAX_TIME_INDEX = get_time_index(datetime.now())

# %% [markdown]
# ## データ読み込み

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### 処理済みデータ

# %%
df_main = pd.read_table(without_stopwords_text_file)

df_main.head(2)
# Out:
#                   date  link_index  number  \
# 0  2017/10/30|23/00/00       18471      19
# 1  2009/01/07|23/05/00        4800     211
#
#                                              content  \
# 0   東京大学　新卒就職先トップ１０   　　　　＜２０１１年＞　　　　　　　＜２０１２年＞　　...
# 1   ■東大生の選んだ法科大学院ランキング■  http://changi.2ch.net/te...
#
#                                     disassembled_all  \
# 0  *<334>トウキョウ<334>大学<334>　<334>新卒<334>就職<334>先<3...
# 1  *<334>■<334>東大<334>生<334>の<334>選ぶ<334>た<334>法科...
#
#                                  disassembled_target Sentiment
# 0  トウキョウ<334>大学<334>新卒<334>就職<334>先<334>トップ-top<3...       pos
# 1  東大<334>法科<334>大学<334>ランキング-ranking<334>http<33...       neu

# %% [markdown]
# ### 本ノート用キーワード

# %%
with open(keywords_file, "r", encoding="utf-8") as f:
    keywords = f.read().split()

keywords
# Out:
# ['馬鹿', 'コンプ', '逮捕', '社会', '就職']

# %% [markdown]
# ### 母集団からのTFIDFモデルをサルベージ

# %%
import pickle
from copy import deepcopy

def tokenize(text):
    return text.split(TOKEN_DIVIDER)

with open(tfidf_model_file, "rb") as f:
    tfidf_model = pickle.load(f)

#対象（名詞・形容詞）を見せる用
tfidf_model_showing = deepcopy(tfidf_model)
tfidf_model_showing.ngram = (1,1)
tfidf_model_showing.tokenizer = tokenize

# %% [markdown]
# ## 分析

# %% [markdown]
# ### 各テキストに時期インデックスを割り振る

# %%
indices = []

for _, row in df_main.iterrows():
    indices.append(get_time_index(convert_time(row["date"])))

df_main["time_index"] = indices

df_main.head(3)
# Out:
#                   date  link_index  number  \
# 0  2017/10/30|23/00/00       18471      19
# 1  2009/01/07|23/05/00        4800     211
# 2  2001/01/21|02/07/00       48612     186
#
#                                              content  \
# 0   東京大学　新卒就職先トップ１０   　　　　＜２０１１年＞　　　　　　　＜２０１２年＞　　...
# 1   ■東大生の選んだ法科大学院ランキング■  http://changi.2ch.net/te...
# 2                                         >184  東大生？
#
#                                     disassembled_all  \
# 0  *<334>トウキョウ<334>大学<334>　<334>新卒<334>就職<334>先<3...
# 1  *<334>■<334>東大<334>生<334>の<334>選ぶ<334>た<334>法科...
# 2           *<334>＞<334>184<334>東大<334>生<334>？<334>*
#
#                                  disassembled_target Sentiment  time_index
# 0  トウキョウ<334>大学<334>新卒<334>就職<334>先<334>トップ-top<3...       pos        17.0
# 1  東大<334>法科<334>大学<334>ランキング-ranking<334>http<33...       neu         9.0
# 2                                         184<334>東大       neu         1.0

# %% [markdown]
# ### キーワードごとに分析

# %%
from IPython.display import display

#キーワードごとに
for keyword in keywords:
    scores = []
    coocs = []
    counts = []

    #時期インデックスごとに
    for time_index in range(MAX_TIME_INDEX):
        #極性スコア計算
        score = 0
        cnt = 0
        texts = []
        for _, row in df_main[df_main["time_index"] == time_index].iterrows():
            if keyword in row["disassembled_all"].split(TOKEN_DIVIDER):
                cnt += 1
                if row["Sentiment"] == "pos":
                    score += 1
                elif row["Sentiment"] == "neg":
                    score -= 1
                texts.append(row["disassembled_target"])
        if cnt != 0:
            score /= cnt
        else:
            score = 0
        
        ##共起
        #TFIDF計算
        if cnt != 0:
            tfidf_spycy = tfidf_model_showing.transform(texts)
            tfidf_df = pd.DataFrame(tfidf_spycy.toarray(), columns=tfidf_model_showing.get_feature_names_out())
            tfidf_mean = tfidf_df.mean(axis=0)

            #単語名と結び付け
            tfidf_mean = tfidf_mean.sort_values(ascending=False)

            #ストップワードの削除
            for word in local_stopwords:
                try:
                    tfidf_mean = tfidf_mean.drop(word)
                except:
                    pass

            if len(tfidf_mean) > 1:
                cooc = ", ".join(tfidf_mean[1:min(6, len(tfidf_mean))].index)
            else:
                cooc = ""
        else:
            cooc = ""
        
        scores.append(score)
        coocs.append(cooc)
        counts.append(cnt)

    df_keyword = pd.DataFrame(list(zip(counts, scores, coocs)), columns=["Count", "Score", "CoOccure"])

    print("\n"+keyword)
    display(df_keyword.style.bar(subset=["Score"], align='zero', color=['#d65f5f', '#5fba7d'], vmax=1, vmin=-1))
# Out:
# 馬鹿
# <style type="text/css">
# #T_7d64c_row0_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 9.1%, #d65f5f 9.1%, #d65f5f 50.0%, transparent 50.0%);
# }
# #T_7d64c_row1_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 13.6%, #d65f5f 13.6%, #d65f5f 50.0%, transparent 50.0%);
# }
# #T_7d64c_row2_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 8.7%, #d65f5f 8.7%, #d65f5f 50.0%, transparent 50.0%);
# }
# #T_7d64c_row3_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 9.6%, #d65f5f 9.6%, #d65f5f 50.0%, transparent 50.0%);
# }
# #T_7d64c_row4_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 15.4%, #d65f5f 15.4%, #d65f5f 50.0%, transparent 50.0%);
# }
# #T_7d64c_row5_col1, #T_7d64c_row15_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 12.5%, #d65f5f 12.5%, #d65f5f 50.0%, transparent 50.0%);
# }
# #T_7d64c_row6_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 10.8%, #d65f5f 10.8%, #d65f5f 50.0%, transparent 50.0%);
# }
# #T_7d64c_row7_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 22.5%, #d65f5f 22.5%, #d65f5f 50.0%, transparent 50.0%);
# }
# #T_7d64c_row8_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 9.2%, #d65f5f 9.2%, #d65f5f 50.0%, transparent 50.0%);
# }
# #T_7d64c_row9_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 14.3%, #d65f5f 14.3%, #d65f5f 50.0%, transparent 50.0%);
# }
# #T_7d64c_row10_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 9.5%, #d65f5f 9.5%, #d65f5f 50.0%, transparent 50.0%);
# }
# #T_7d64c_row11_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 4.7%, #d65f5f 4.7%, #d65f5f 50.0%, transparent 50.0%);
# }
# #T_7d64c_row12_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 16.2%, #d65f5f 16.2%, #d65f5f 50.0%, transparent 50.0%);
# }
# #T_7d64c_row13_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 16.0%, #d65f5f 16.0%, #d65f5f 50.0%, transparent 50.0%);
# }
# #T_7d64c_row14_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 2.8%, #d65f5f 2.8%, #d65f5f 50.0%, transparent 50.0%);
# }
# #T_7d64c_row16_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 38.9%, #d65f5f 38.9%, #d65f5f 50.0%, transparent 50.0%);
# }
# #T_7d64c_row17_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 25.0%, #d65f5f 25.0%, #d65f5f 50.0%, transparent 50.0%);
# }
# #T_7d64c_row18_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 33.3%, #d65f5f 33.3%, #d65f5f 50.0%, transparent 50.0%);
# }
# #T_7d64c_row19_col1, #T_7d64c_row20_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 50.0%, transparent 50.0%);
# }
# #T_7d64c_row21_col1, #T_7d64c_row22_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 100.0%, transparent 100.0%);
# }
# </style>
# <table id="T_7d64c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7d64c_level0_col0" class="col_heading level0 col0" >Count</th>
#       <th id="T_7d64c_level0_col1" class="col_heading level0 col1" >Score</th>
#       <th id="T_7d64c_level0_col2" class="col_heading level0 col2" >CoOccure</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7d64c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7d64c_row0_col0" class="data row0 col0" >22</td>
#       <td id="T_7d64c_row0_col1" class="data row0 col1" >-0.818182</td>
#       <td id="T_7d64c_row0_col2" class="data row0 col2" >馬鹿 東大, 多い, 大学, 凄い, 奴</td>
#     </tr>
#     <tr>
#       <th id="T_7d64c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_7d64c_row1_col0" class="data row1 col0" >236</td>
#       <td id="T_7d64c_row1_col1" class="data row1 col1" >-0.728814</td>
#       <td id="T_7d64c_row1_col2" class="data row1 col2" >馬鹿 東大, 事, 藁, 奴, 大学</td>
#     </tr>
#     <tr>
#       <th id="T_7d64c_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_7d64c_row2_col0" class="data row2 col0" >149</td>
#       <td id="T_7d64c_row2_col1" class="data row2 col1" >-0.825503</td>
#       <td id="T_7d64c_row2_col2" class="data row2 col2" >馬鹿 東大, 良い, 事, 頭, 頭 良い</td>
#     </tr>
#     <tr>
#       <th id="T_7d64c_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_7d64c_row3_col0" class="data row3 col0" >166</td>
#       <td id="T_7d64c_row3_col1" class="data row3 col1" >-0.807229</td>
#       <td id="T_7d64c_row3_col2" class="data row3 col2" >事, オカ, ｗ, 学歴, 03</td>
#     </tr>
#     <tr>
#       <th id="T_7d64c_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_7d64c_row4_col0" class="data row4 col0" >107</td>
#       <td id="T_7d64c_row4_col1" class="data row4 col1" >-0.691589</td>
#       <td id="T_7d64c_row4_col2" class="data row4 col2" >大学, 事, 慶応, 自分, 良い</td>
#     </tr>
#     <tr>
#       <th id="T_7d64c_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_7d64c_row5_col0" class="data row5 col0" >84</td>
#       <td id="T_7d64c_row5_col1" class="data row5 col1" >-0.750000</td>
#       <td id="T_7d64c_row5_col2" class="data row5 col2" >事, ｗ, 馬鹿 東大, 大学, 奴</td>
#     </tr>
#     <tr>
#       <th id="T_7d64c_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_7d64c_row6_col0" class="data row6 col0" >102</td>
#       <td id="T_7d64c_row6_col1" class="data row6 col1" >-0.784314</td>
#       <td id="T_7d64c_row6_col2" class="data row6 col2" >事, 早慶, 馬鹿 東大, ｗ, 大学</td>
#     </tr>
#     <tr>
#       <th id="T_7d64c_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_7d64c_row7_col0" class="data row7 col0" >69</td>
#       <td id="T_7d64c_row7_col1" class="data row7 col1" >-0.550725</td>
#       <td id="T_7d64c_row7_col2" class="data row7 col2" >駅弁, 大学, 事, 東大 医, ワセダ</td>
#     </tr>
#     <tr>
#       <th id="T_7d64c_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_7d64c_row8_col0" class="data row8 col0" >65</td>
#       <td id="T_7d64c_row8_col1" class="data row8 col1" >-0.815385</td>
#       <td id="T_7d64c_row8_col2" class="data row8 col2" >大学, 事, ｗ, 奴, 多い</td>
#     </tr>
#     <tr>
#       <th id="T_7d64c_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_7d64c_row9_col0" class="data row9 col0" >49</td>
#       <td id="T_7d64c_row9_col1" class="data row9 col1" >-0.714286</td>
#       <td id="T_7d64c_row9_col2" class="data row9 col2" >ｗ, 大学, 事, 早慶, 受験</td>
#     </tr>
#     <tr>
#       <th id="T_7d64c_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_7d64c_row10_col0" class="data row10 col0" >42</td>
#       <td id="T_7d64c_row10_col1" class="data row10 col1" >-0.809524</td>
#       <td id="T_7d64c_row10_col2" class="data row10 col2" >大学, 法政, 明治, 事, 括り</td>
#     </tr>
#     <tr>
#       <th id="T_7d64c_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_7d64c_row11_col0" class="data row11 col0" >74</td>
#       <td id="T_7d64c_row11_col1" class="data row11 col1" >-0.905405</td>
#       <td id="T_7d64c_row11_col2" class="data row11 col2" >大学, 明治, 事, 括り, ワセダ</td>
#     </tr>
#     <tr>
#       <th id="T_7d64c_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_7d64c_row12_col0" class="data row12 col0" >40</td>
#       <td id="T_7d64c_row12_col1" class="data row12 col1" >-0.675000</td>
#       <td id="T_7d64c_row12_col2" class="data row12 col2" >京大, 良い, 学生, 南山, 大学</td>
#     </tr>
#     <tr>
#       <th id="T_7d64c_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_7d64c_row13_col0" class="data row13 col0" >25</td>
#       <td id="T_7d64c_row13_col1" class="data row13 col1" >-0.680000</td>
#       <td id="T_7d64c_row13_col2" class="data row13 col2" >理工, 3, 52, 理, 56</td>
#     </tr>
#     <tr>
#       <th id="T_7d64c_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_7d64c_row14_col0" class="data row14 col0" >18</td>
#       <td id="T_7d64c_row14_col1" class="data row14 col1" >-0.944444</td>
#       <td id="T_7d64c_row14_col2" class="data row14 col2" >地方 公務, メガ-me
# コンプ
# <style type="text/css">
# #T_6a04e_row0_col1, #T_6a04e_row19_col1, #T_6a04e_row22_col1 {
#   width: 10em;
# }
# #T_6a04e_row1_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 13.8%, #d65f5f 13.8%, #d65f5f 50.0%, transparent 50.0%);
# }
# #T_6a04e_row2_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 15.0%, #d65f5f 15.0%, #d65f5f 50.0%, transparent 50.0%);
# }
# #T_6a04e_row3_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 8.6%, #d65f5f 8.6%, #d65f5f 50.0%, transparent 50.0%);
# }
# #T_6a04e_row4_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 8.0%, #d65f5f 8.0%, #d65f5f 50.0%, transparent 50.0%);
# }
# #T_6a04e_row5_col1, #T_6a04e_row8_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 18.5%, #d65f5f 18.5%, #d65f5f 50.0%, transparent 50.0%);
# }
# #T_6a04e_row6_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 26.3%, #d65f5f 26.3%, #d65f5f 50.0%, transparent 50.0%);
# }
# #T_6a04e_row7_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 12.5%, #d65f5f 12.5%, #d65f5f 50.0%, transparent 50.0%);
# }
# #T_6a04e_row9_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 4.5%, #d65f5f 4.5%, #d65f5f 50.0%, transparent 50.0%);
# }
# #T_6a04e_row10_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 4.4%, #d65f5f 4.4%, #d65f5f 50.0%, transparent 50.0%);
# }
# #T_6a04e_row11_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 6.8%, #d65f5f 6.8%, #d65f5f 50.0%, transparent 50.0%);
# }
# #T_6a04e_row12_col1, #T_6a04e_row14_col1, #T_6a04e_row16_col1, #T_6a04e_row17_col1, #T_6a04e_row20_col1, #T_6a04e_row21_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 50.0%, transparent 50.0%);
# }
# #T_6a04e_row13_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 7.1%, #d65f5f 7.1%, #d65f5f 50.0%, transparent 50.0%);
# }
# #T_6a04e_row15_col1, #T_6a04e_row18_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 25.0%, #d65f5f 25.0%, #d65f5f 50.0%, transparent 50.0%);
# }
# </style>
# <table id="T_6a04e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6a04e_level0_col0" class="col_heading level0 col0" >Count</th>
#       <th id="T_6a04e_level0_col1" class="col_heading level0 col1" >Score</th>
#       <th id="T_6a04e_level0_col2" class="col_heading level0 col2" >CoOccure</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6a04e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6a04e_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_6a04e_row0_col1" class="data row0 col1" >0.000000</td>
#       <td id="T_6a04e_row0_col2" class="data row0 col2" ></td>
#     </tr>
#     <tr>
#       <th id="T_6a04e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_6a04e_row1_col0" class="data row1 col0" >40</td>
#       <td id="T_6a04e_row1_col1" class="data row1 col1" >-0.725000</td>
#       <td id="T_6a04e_row1_col2" class="data row1 col2" >教養, ﾜﾗ, 部, ヒトツバシ, 経済</td>
#     </tr>
#     <tr>
#       <th id="T_6a04e_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_6a04e_row2_col0" class="data row2 col0" >40</td>
#       <td id="T_6a04e_row2_col1" class="data row2 col1" >-0.700000</td>
#       <td id="T_6a04e_row2_col2" class="data row2 col2" >教養, ヒトツバシ, セキ 爺, 経, セキ</td>
#     </tr>
#     <tr>
#       <th id="T_6a04e_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_6a04e_row3_col0" class="data row3 col0" >29</td>
#       <td id="T_6a04e_row3_col1" class="data row3 col1" >-0.827586</td>
#       <td id="T_6a04e_row3_col2" class="data row3 col2" >医学 部, 東大 コンプ, 医学, 部, 慶応</td>
#     </tr>
#     <tr>
#       <th id="T_6a04e_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_6a04e_row4_col0" class="data row4 col0" >25</td>
#       <td id="T_6a04e_row4_col1" class="data row4 col1" >-0.840000</td>
#       <td id="T_6a04e_row4_col2" class="data row4 col2" >東大 コンプ, 医学 部, 部, 医学, ｗ</td>
#     </tr>
#     <tr>
#       <th id="T_6a04e_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_6a04e_row5_col0" class="data row5 col0" >27</td>
#       <td id="T_6a04e_row5_col1" class="data row5 col1" >-0.629630</td>
#       <td id="T_6a04e_row5_col2" class="data row5 col2" >ｗ, 東大 コンプ, 部, 医学 部, 医学</td>
#     </tr>
#     <tr>
#       <th id="T_6a04e_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_6a04e_row6_col0" class="data row6 col0" >38</td>
#       <td id="T_6a04e_row6_col1" class="data row6 col1" >-0.473684</td>
#       <td id="T_6a04e_row6_col2" class="data row6 col2" >学歴, 東大 コンプ, 部, 医学 部, 医学</td>
#     </tr>
#     <tr>
#       <th id="T_6a04e_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_6a04e_row7_col0" class="data row7 col0" >36</td>
#       <td id="T_6a04e_row7_col1" class="data row7 col1" >-0.750000</td>
#       <td id="T_6a04e_row7_col2" class="data row7 col2" >東大 コンプ, 慶応, 京大, 学歴 コンプ, 大学</td>
#     </tr>
#     <tr>
#       <th id="T_6a04e_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_6a04e_row8_col0" class="data row8 col0" >27</td>
#       <td id="T_6a04e_row8_col1" class="data row8 col1" >-0.629630</td>
#       <td id="T_6a04e_row8_col2" class="data row8 col2" >京大, 東大 コンプ, id, 2008, 6</td>
#     </tr>
#     <tr>
#       <th id="T_6a04e_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_6a04e_row9_col0" class="data row9 col0" >11</td>
#       <td id="T_6a04e_row9_col1" class="data row9 col1" >-0.909091</td>
#       <td id="T_6a04e_row9_col2" class="data row9 col2" >京大, 丸出し, 日本 一, 単位, 就活</td>
#     </tr>
#     <tr>
#       <th id="T_6a04e_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_6a04e_row10_col0" class="data row10 col0" >34</td>
#       <td id="T_6a04e_row10_col1" class="data row10 col1" >-0.911765</td>
#       <td id="T_6a04e_row10_col2" class="data row10 col2" >法政, 明治, 御頭, 大学, 慶応</td>
#     </tr>
#     <tr>
#       <th id="T_6a04e_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_6a04e_row11_col0" class="data row11 col0" >37</td>
#       <td id="T_6a04e_row11_col1" class="data row11 col1" >-0.864865</td>
#       <td id="T_6a04e_row11_col2" class="data row11 col2" >コンプ, 法政, 大学, 括り, 六</td>
#     </tr>
#     <tr>
#       <th id="T_6a04e_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_6a04e_row12_col0" class="data row12 col0" >16</td>
#       <td id="T_6a04e_row12_col1" class="data row12 col1" >-1.000000</td>
#       <td id="T_6a04e_row12_col2" class="data row12 col2" >学歴, 学歴 コンプ, 監視, 事, スレ-thread</td>
#     </tr>
#     <tr>
#       <th id="T_6a04e_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_6a04e_row13_col0" class="data row13 col0" >7</td>
#       <td id="T_6a04e_row13_col1" class="data row13 col1" >-0.857143</td>
#       <td id="T_6a04e_row13_col2" class="data row13 col2" >学歴 コンプ, 学歴, 東大 コンプ, 一 工, トウキョウ 一</td>
#     </tr>
#     <tr>
#       <th id="T_6a04e_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_6a04e_row14_col0" class="data row14 col0" >2</td>
#       <td id="T_6a04e_row14_col1" class="data row14 col1" >-1.000000</td>
#       <td id="T_6a04e_row14_col2" class="data row14 col2" >土, 学歴 コンプ, エリート-elite 街道, 街道, 一流</td>
#     </tr>
#     <tr>
#       <th id="T_6a04e_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_6a04e_row15_col0" class="data row15 col0" >2</td>
#       <td id="T_6a04e_row15_col1" class="data row15 col1" >-0.500000</td>
#       <td id="T_6a04e_row15_col2" class="data row15 col2" >九大, 東大 京大, 風, 旧 帝, 帝</td>
#     </tr>
#     <tr>
#       <th id="T_6a04e_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_6a04e_row16_col0" class="data row16 col0" >3</td>
#       <td id="T_6a04e_row16_col1" class="data row16 col1" >-1.000000</td>
#       <td id="T_6a04e_row16_col2" class="data row16 col2" >コンプ, 無い 東大, 学歴, 医学, 医学 部</td>
#     </tr>
#     <tr>
#       <th id="T_6a04e_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_6a04e_row17_col0" class
# 逮捕
# <style type="text/css">
# #T_decbe_row0_col1, #T_decbe_row9_col1, #T_decbe_row10_col1, #T_decbe_row12_col1, #T_decbe_row14_col1, #T_decbe_row15_col1, #T_decbe_row21_col1, #T_decbe_row22_col1 {
#   width: 10em;
# }
# #T_decbe_row1_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 16.7%, #d65f5f 16.7%, #d65f5f 50.0%, transparent 50.0%);
# }
# #T_decbe_row2_col1, #T_decbe_row8_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 8.3%, #d65f5f 8.3%, #d65f5f 50.0%, transparent 50.0%);
# }
# #T_decbe_row3_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 19.2%, #d65f5f 19.2%, #d65f5f 50.0%, transparent 50.0%);
# }
# #T_decbe_row4_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 20.0%, #d65f5f 20.0%, #d65f5f 50.0%, transparent 50.0%);
# }
# #T_decbe_row5_col1, #T_decbe_row7_col1, #T_decbe_row11_col1, #T_decbe_row13_col1, #T_decbe_row17_col1, #T_decbe_row19_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 50.0%, transparent 50.0%);
# }
# #T_decbe_row6_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 63.6%, transparent 63.6%);
# }
# #T_decbe_row16_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 30.8%, #d65f5f 30.8%, #d65f5f 50.0%, transparent 50.0%);
# }
# #T_decbe_row18_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 100.0%, transparent 100.0%);
# }
# #T_decbe_row20_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 12.5%, #d65f5f 12.5%, #d65f5f 50.0%, transparent 50.0%);
# }
# </style>
# <table id="T_decbe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_decbe_level0_col0" class="col_heading level0 col0" >Count</th>
#       <th id="T_decbe_level0_col1" class="col_heading level0 col1" >Score</th>
#       <th id="T_decbe_level0_col2" class="col_heading level0 col2" >CoOccure</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_decbe_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_decbe_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_decbe_row0_col1" class="data row0 col1" >0.000000</td>
#       <td id="T_decbe_row0_col2" class="data row0 col2" ></td>
#     </tr>
#     <tr>
#       <th id="T_decbe_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_decbe_row1_col0" class="data row1 col0" >3</td>
#       <td id="T_decbe_row1_col1" class="data row1 col1" >-0.666667</td>
#       <td id="T_decbe_row1_col2" class="data row1 col2" >natto, tsol, key, bbs, joke</td>
#     </tr>
#     <tr>
#       <th id="T_decbe_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_decbe_row2_col0" class="data row2 col0" >6</td>
#       <td id="T_decbe_row2_col1" class="data row2 col1" >-0.833333</td>
#       <td id="T_decbe_row2_col2" class="data row2 col2" >レイプ-rape, ニュース-news, 画像, 大学, 流出</td>
#     </tr>
#     <tr>
#       <th id="T_decbe_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_decbe_row3_col0" class="data row3 col0" >39</td>
#       <td id="T_decbe_row3_col1" class="data row3 col1" >-0.615385</td>
#       <td id="T_decbe_row3_col2" class="data row3 col2" >容疑, 事件, 暴行, 月, スーパー-super フリー-free</td>
#     </tr>
#     <tr>
#       <th id="T_decbe_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_decbe_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_decbe_row4_col1" class="data row4 col1" >-0.600000</td>
#       <td id="T_decbe_row4_col2" class="data row4 col2" >女子, 現行, 時, top, セックス-sex</td>
#     </tr>
#     <tr>
#       <th id="T_decbe_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_decbe_row5_col0" class="data row5 col0" >2</td>
#       <td id="T_decbe_row5_col1" class="data row5 col1" >-1.000000</td>
#       <td id="T_decbe_row5_col2" class="data row5 col2" >処分, カイセイ, 退学, 拒否, 妨害</td>
#     </tr>
#     <tr>
#       <th id="T_decbe_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_decbe_row6_col0" class="data row6 col0" >11</td>
#       <td id="T_decbe_row6_col1" class="data row6 col1" >0.272727</td>
#       <td id="T_decbe_row6_col2" class="data row6 col2" >学生, 事件, 女子, 部, 灯台</td>
#     </tr>
#     <tr>
#       <th id="T_decbe_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_decbe_row7_col0" class="data row7 col0" >2</td>
#       <td id="T_decbe_row7_col1" class="data row7 col1" >-1.000000</td>
#       <td id="T_decbe_row7_col2" class="data row7 col2" >事件, 月, 逮捕, 府, 10 月</td>
#     </tr>
#     <tr>
#       <th id="T_decbe_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_decbe_row8_col0" class="data row8 col0" >6</td>
#       <td id="T_decbe_row8_col1" class="data row8 col1" >-0.833333</td>
#       <td id="T_decbe_row8_col2" class="data row8 col2" >逮捕, 無職, yahoo, 博士, 脅迫</td>
#     </tr>
#     <tr>
#       <th id="T_decbe_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_decbe_row9_col0" class="data row9 col0" >0</td>
#       <td id="T_decbe_row9_col1" class="data row9 col1" >0.000000</td>
#       <td id="T_decbe_row9_col2" class="data row9 col2" ></td>
#     </tr>
#     <tr>
#       <th id="T_decbe_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_decbe_row10_col0" class="data row10 col0" >0</td>
#       <td id="T_decbe_row10_col1" class="data row10 col1" >0.000000</td>
#       <td id="T_decbe_row10_col2" class="data row10 col2" ></td>
#     </tr>
#     <tr>
#       <th id="T_decbe_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_decbe_row11_col0" class="data row11 col0" >1</td>
#       <td id="T_decbe_row11_col1" class="data row11 col1" >-1.000000</td>
#       <td id="T_decbe_row11_col2" class="data row11 col2" >492, 495, 487, 馬鹿, 猿</td>
#     </tr>
#     <tr>
#       <th id="T_decbe_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_decbe_row12_col0" class="data row12 col0" >0</td>
#       <td id="T_decbe_row12_col1" class="data row12 col1" >0.000000</td>
#       <td id="T_decbe_row12_col2" class="data row12 col2" ></td>
#     </tr>
#     <tr>
#       <th id="T_decbe_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_decbe_row13_col0" class="data row13 col0" >1</td>
#       <td id="T_decbe_row13_col1" class="data row13 col1" >-1.000000</td>
#       <td id="T_decbe_row13_col2" class="data row13 col2" >2009, 年, 課題, 2011 年, 2010 年</td>
#     </tr>
#     <tr>
#       <th id="T_decbe_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_decbe_row14_col0" class="data row14 col0" >0</td>
#       <td id="T_decbe_row14_col1" class="data row14 col1" >0.000000</td>
#       <td id="T_decbe_row14_col2" class="data row14 col2" ></td>
#     </tr>
#     <tr>
#       <th id="T_decbe_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_decbe_row15_col0" class="data row15 col0" >0</td>
#       <td id="T_decbe_row15_col1" class="data row15 col1" >0.000000</td>
#       <td id="T_decbe_row15_col2" class="data row15 col2" ></td>
#     </tr>
#     <tr>
#       <th id="T_decbe_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_decbe_row16_col0" class="data row16 col0" >13</td>
#       <td id="T_decbe_row16_col1" class="data row16 col1" >-0.384615</td>
#       <td id="T_decbe_row16_col2" class="data row16 col2" >ケン, ユウ, 強制, 東大 大学, 大学</td>
#     </tr>
#     <tr>
#       <th id="T_decbe_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_decbe_row17_col0" class="data row17 col0" >1</td>
#       <td id="T_decbe_row17_col1" class="data row17 col1" >-1.000000</td>
#       <td id="T_decbe_row17_col2" class="data row17 col2" >強姦, 起訴, 事件, 被害, ヤマダ</td>
#     </tr>
#     <tr>
#       <th id="T_decbe_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_decbe_row18_col0" class="data row18 col0" >1</td>
#       <td id="T_decbe_row18_col1" class="data row18 col1" >1.000000</td>
#       <td id="T_decbe_row18_col2" class="data row18 col2" >ミスター-mister, ツイッター-twitter, 写真, タレント-talent, エロ-erotic</td>
#     </tr>
#     <tr>
#       <th id="T_decbe_level0_row19" class="row_heading
# 社会
# <style type="text/css">
# #T_0f37d_row0_col1, #T_0f37d_row20_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 5.6%, #d65f5f 5.6%, #d65f5f 50.0%, transparent 50.0%);
# }
# #T_0f37d_row1_col1, #T_0f37d_row8_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 12.9%, #d65f5f 12.9%, #d65f5f 50.0%, transparent 50.0%);
# }
# #T_0f37d_row2_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 13.5%, #d65f5f 13.5%, #d65f5f 50.0%, transparent 50.0%);
# }
# #T_0f37d_row3_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 21.7%, #d65f5f 21.7%, #d65f5f 50.0%, transparent 50.0%);
# }
# #T_0f37d_row4_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 17.9%, #d65f5f 17.9%, #d65f5f 50.0%, transparent 50.0%);
# }
# #T_0f37d_row5_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 9.7%, #d65f5f 9.7%, #d65f5f 50.0%, transparent 50.0%);
# }
# #T_0f37d_row6_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 20.4%, #d65f5f 20.4%, #d65f5f 50.0%, transparent 50.0%);
# }
# #T_0f37d_row7_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 22.8%, #d65f5f 22.8%, #d65f5f 50.0%, transparent 50.0%);
# }
# #T_0f37d_row9_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 6.0%, #d65f5f 6.0%, #d65f5f 50.0%, transparent 50.0%);
# }
# #T_0f37d_row10_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 5.8%, #d65f5f 5.8%, #d65f5f 50.0%, transparent 50.0%);
# }
# #T_0f37d_row11_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 2.9%, #d65f5f 2.9%, #d65f5f 50.0%, transparent 50.0%);
# }
# #T_0f37d_row12_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 17.7%, #d65f5f 17.7%, #d65f5f 50.0%, transparent 50.0%);
# }
# #T_0f37d_row13_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 44.4%, #d65f5f 44.4%, #d65f5f 50.0%, transparent 50.0%);
# }
# #T_0f37d_row14_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 76.0%, transparent 76.0%);
# }
# #T_0f37d_row15_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 40.0%, #d65f5f 40.0%, #d65f5f 50.0%, transparent 50.0%);
# }
# #T_0f37d_row16_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 60.0%, transparent 60.0%);
# }
# #T_0f37d_row17_col1, #T_0f37d_row22_col1 {
#   width: 10em;
# }
# #T_0f37d_row18_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 50.0%, transparent 50.0%);
# }
# #T_0f37d_row19_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 20.0%, #d65f5f 20.0%, #d65f5f 50.0%, transparent 50.0%);
# }
# #T_0f37d_row21_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 16.7%, #d65f5f 16.7%, #d65f5f 50.0%, transparent 50.0%);
# }
# </style>
# <table id="T_0f37d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0f37d_level0_col0" class="col_heading level0 col0" >Count</th>
#       <th id="T_0f37d_level0_col1" class="col_heading level0 col1" >Score</th>
#       <th id="T_0f37d_level0_col2" class="col_heading level0 col2" >CoOccure</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0f37d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0f37d_row0_col0" class="data row0 col0" >9</td>
#       <td id="T_0f37d_row0_col1" class="data row0 col1" >-0.888889</td>
#       <td id="T_0f37d_row0_col2" class="data row0 col2" >学歴, エリート-elite, 学歴 社会, 作戦, 国家</td>
#     </tr>
#     <tr>
#       <th id="T_0f37d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_0f37d_row1_col0" class="data row1 col0" >85</td>
#       <td id="T_0f37d_row1_col1" class="data row1 col1" >-0.741176</td>
#       <td id="T_0f37d_row1_col2" class="data row1 col2" >良い, 事, 大学, 部, 無い 東大</td>
#     </tr>
#     <tr>
#       <th id="T_0f37d_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_0f37d_row2_col0" class="data row2 col0" >52</td>
#       <td id="T_0f37d_row2_col1" class="data row2 col1" >-0.730769</td>
#       <td id="T_0f37d_row2_col2" class="data row2 col2" >事, 学歴, 人間, 大学, 奴</td>
#     </tr>
#     <tr>
#       <th id="T_0f37d_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_0f37d_row3_col0" class="data row3 col0" >76</td>
#       <td id="T_0f37d_row3_col1" class="data row3 col1" >-0.565789</td>
#       <td id="T_0f37d_row3_col2" class="data row3 col2" >事, 大学, 勉強, ワセダ, 慶応</td>
#     </tr>
#     <tr>
#       <th id="T_0f37d_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_0f37d_row4_col0" class="data row4 col0" >84</td>
#       <td id="T_0f37d_row4_col1" class="data row4 col1" >-0.642857</td>
#       <td id="T_0f37d_row4_col2" class="data row4 col2" >事, 多い, 人, 大学, 人間</td>
#     </tr>
#     <tr>
#       <th id="T_0f37d_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_0f37d_row5_col0" class="data row5 col0" >36</td>
#       <td id="T_0f37d_row5_col1" class="data row5 col1" >-0.805556</td>
#       <td id="T_0f37d_row5_col2" class="data row5 col2" >学歴, 日本, 受験, 756, 学生</td>
#     </tr>
#     <tr>
#       <th id="T_0f37d_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_0f37d_row6_col0" class="data row6 col0" >27</td>
#       <td id="T_0f37d_row6_col1" class="data row6 col1" >-0.592593</td>
#       <td id="T_0f37d_row6_col2" class="data row6 col2" >医学, 医学 部, 事, 学歴, 部</td>
#     </tr>
#     <tr>
#       <th id="T_0f37d_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_0f37d_row7_col0" class="data row7 col0" >57</td>
#       <td id="T_0f37d_row7_col1" class="data row7 col1" >-0.543860</td>
#       <td id="T_0f37d_row7_col2" class="data row7 col2" >国語, 事, 天才, 大学, 記憶</td>
#     </tr>
#     <tr>
#       <th id="T_0f37d_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_0f37d_row8_col0" class="data row8 col0" >31</td>
#       <td id="T_0f37d_row8_col1" class="data row8 col1" >-0.741935</td>
#       <td id="T_0f37d_row8_col2" class="data row8 col2" >早慶, 大学, 博士, 389, 事</td>
#     </tr>
#     <tr>
#       <th id="T_0f37d_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_0f37d_row9_col0" class="data row9 col0" >25</td>
#       <td id="T_0f37d_row9_col1" class="data row9 col1" >-0.880000</td>
#       <td id="T_0f37d_row9_col2" class="data row9 col2" >就職, 入学, ワセダ, 慶応, 一</td>
#     </tr>
#     <tr>
#       <th id="T_0f37d_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_0f37d_row10_col0" class="data row10 col0" >26</td>
#       <td id="T_0f37d_row10_col1" class="data row10 col1" >-0.884615</td>
#       <td id="T_0f37d_row10_col2" class="data row10 col2" >受験, 数学, ワセダ, 合格, 勉強</td>
#     </tr>
#     <tr>
#       <th id="T_0f37d_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_0f37d_row11_col0" class="data row11 col0" >34</td>
#       <td id="T_0f37d_row11_col1" class="data row11 col1" >-0.941176</td>
#       <td id="T_0f37d_row11_col2" class="data row11 col2" >事, 受験, 大学, 科目, 数学</td>
#     </tr>
#     <tr>
#       <th id="T_0f37d_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_0f37d_row12_col0" class="data row12 col0" >31</td>
#       <td id="T_0f37d_row12_col1" class="data row12 col1" >-0.645161</td>
#       <td id="T_0f37d_row12_col2" class="data row12 col2" >部, 評価, 文系, 能力, ワセダ</td>
#     </tr>
#     <tr>
#       <th id="T_0f37d_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_0f37d_row13_col0" class="data row13 col0" >9</td>
#       <td id="T_0f37d_row13_col1" class="data row13 col1" >-0.111111</td>
#       <td id="T_0f37d_row13_col2" class="data row13 col2" >企業, 社会, http, 大学, html</td>
#     </tr>
#     <tr>
#       <th id="T_0f37d_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_0f37d_row14_col0" class="data row14 col0" >25</td>
#       <td id="T_0f37d_row14_col1" class="data row14 col1" >0.520000</td>
#       <td id="T_0f37d_row14_col2" class="data row14 col2" >早慶 march, アオヤマ, 学歴, ランク-rank, 法政</td>
#     </tr>
#     <tr>
#       <th id="T_0f37d_level0_row15" class="row_headi
# 就職
# <style type="text/css">
# #T_99c50_row0_col1, #T_99c50_row16_col1, #T_99c50_row20_col1, #T_99c50_row21_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 50.0%, transparent 50.0%);
# }
# #T_99c50_row1_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 12.8%, #d65f5f 12.8%, #d65f5f 50.0%, transparent 50.0%);
# }
# #T_99c50_row2_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 11.0%, #d65f5f 11.0%, #d65f5f 50.0%, transparent 50.0%);
# }
# #T_99c50_row3_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 36.5%, #d65f5f 36.5%, #d65f5f 50.0%, transparent 50.0%);
# }
# #T_99c50_row4_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 25.4%, #d65f5f 25.4%, #d65f5f 50.0%, transparent 50.0%);
# }
# #T_99c50_row5_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 30.9%, #d65f5f 30.9%, #d65f5f 50.0%, transparent 50.0%);
# }
# #T_99c50_row6_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 13.9%, #d65f5f 13.9%, #d65f5f 50.0%, transparent 50.0%);
# }
# #T_99c50_row7_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 22.9%, #d65f5f 22.9%, #d65f5f 50.0%, transparent 50.0%);
# }
# #T_99c50_row8_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 13.8%, #d65f5f 13.8%, #d65f5f 50.0%, transparent 50.0%);
# }
# #T_99c50_row9_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 15.8%, #d65f5f 15.8%, #d65f5f 50.0%, transparent 50.0%);
# }
# #T_99c50_row10_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 12.5%, #d65f5f 12.5%, #d65f5f 50.0%, transparent 50.0%);
# }
# #T_99c50_row11_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 13.0%, #d65f5f 13.0%, #d65f5f 50.0%, transparent 50.0%);
# }
# #T_99c50_row12_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 10.7%, #d65f5f 10.7%, #d65f5f 50.0%, transparent 50.0%);
# }
# #T_99c50_row13_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 18.0%, #d65f5f 18.0%, #d65f5f 50.0%, transparent 50.0%);
# }
# #T_99c50_row14_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 51.6%, transparent 51.6%);
# }
# #T_99c50_row15_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 38.9%, #d65f5f 38.9%, #d65f5f 50.0%, transparent 50.0%);
# }
# #T_99c50_row17_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 100.0%, transparent 100.0%);
# }
# #T_99c50_row18_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 35.7%, #d65f5f 35.7%, #d65f5f 50.0%, transparent 50.0%);
# }
# #T_99c50_row19_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 4.5%, #d65f5f 4.5%, #d65f5f 50.0%, transparent 50.0%);
# }
# #T_99c50_row22_col1 {
#   width: 10em;
# }
# </style>
# <table id="T_99c50">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_99c50_level0_col0" class="col_heading level0 col0" >Count</th>
#       <th id="T_99c50_level0_col1" class="col_heading level0 col1" >Score</th>
#       <th id="T_99c50_level0_col2" class="col_heading level0 col2" >CoOccure</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_99c50_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_99c50_row0_col0" class="data row0 col0" >8</td>
#       <td id="T_99c50_row0_col1" class="data row0 col1" >-1.000000</td>
#       <td id="T_99c50_row0_col2" class="data row0 col2" >事, 論文, 合格, １８, 東大 合格</td>
#     </tr>
#     <tr>
#       <th id="T_99c50_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_99c50_row1_col0" class="data row1 col0" >94</td>
#       <td id="T_99c50_row1_col1" class="data row1 col1" >-0.744681</td>
#       <td id="T_99c50_row1_col2" class="data row1 col2" >大学, 部, 事, ヒトツバシ, 教養</td>
#     </tr>
#     <tr>
#       <th id="T_99c50_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_99c50_row2_col0" class="data row2 col0" >109</td>
#       <td id="T_99c50_row2_col1" class="data row2 col1" >-0.779817</td>
#       <td id="T_99c50_row2_col2" class="data row2 col2" >教養, ヒトツバシ, 文, 事, 東大 教養</td>
#     </tr>
#     <tr>
#       <th id="T_99c50_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_99c50_row3_col0" class="data row3 col0" >63</td>
#       <td id="T_99c50_row3_col1" class="data row3 col1" >-0.269841</td>
#       <td id="T_99c50_row3_col2" class="data row3 col2" >ワセダ, 大学, 企業, 事, 部</td>
#     </tr>
#     <tr>
#       <th id="T_99c50_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_99c50_row4_col0" class="data row4 col0" >69</td>
#       <td id="T_99c50_row4_col1" class="data row4 col1" >-0.492754</td>
#       <td id="T_99c50_row4_col2" class="data row4 col2" >企業, 大学, 慶応, ８, 法</td>
#     </tr>
#     <tr>
#       <th id="T_99c50_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_99c50_row5_col0" class="data row5 col0" >34</td>
#       <td id="T_99c50_row5_col1" class="data row5 col1" >-0.382353</td>
#       <td id="T_99c50_row5_col2" class="data row5 col2" >企業, ロンダ, 大学, 事, 理系</td>
#     </tr>
#     <tr>
#       <th id="T_99c50_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_99c50_row6_col0" class="data row6 col0" >61</td>
#       <td id="T_99c50_row6_col1" class="data row6 col1" >-0.721311</td>
#       <td id="T_99c50_row6_col2" class="data row6 col2" >大学, 経済, 部, 寄付 講座, 大学 商学 部</td>
#     </tr>
#     <tr>
#       <th id="T_99c50_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_99c50_row7_col0" class="data row7 col0" >48</td>
#       <td id="T_99c50_row7_col1" class="data row7 col1" >-0.541667</td>
#       <td id="T_99c50_row7_col2" class="data row7 col2" >ｗ, ワセダ, 大学, 数, 研究</td>
#     </tr>
#     <tr>
#       <th id="T_99c50_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_99c50_row8_col0" class="data row8 col0" >65</td>
#       <td id="T_99c50_row8_col1" class="data row8 col1" >-0.723077</td>
#       <td id="T_99c50_row8_col2" class="data row8 col2" >企業, 大学, 民間, 企業 就職, 事</td>
#     </tr>
#     <tr>
#       <th id="T_99c50_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_99c50_row9_col0" class="data row9 col0" >38</td>
#       <td id="T_99c50_row9_col1" class="data row9 col1" >-0.684211</td>
#       <td id="T_99c50_row9_col2" class="data row9 col2" >企業, 一, 大学, 日本 一, ワセダ</td>
#     </tr>
#     <tr>
#       <th id="T_99c50_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_99c50_row10_col0" class="data row10 col0" >36</td>
#       <td id="T_99c50_row10_col1" class="data row10 col1" >-0.750000</td>
#       <td id="T_99c50_row10_col2" class="data row10 col2" >明治, 関大, 大学, 市, 面接</td>
#     </tr>
#     <tr>
#       <th id="T_99c50_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_99c50_row11_col0" class="data row11 col0" >69</td>
#       <td id="T_99c50_row11_col1" class="data row11 col1" >-0.739130</td>
#       <td id="T_99c50_row11_col2" class="data row11 col2" >就職, 明治, 学歴, 事, ワセダ</td>
#     </tr>
#     <tr>
#       <th id="T_99c50_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_99c50_row12_col0" class="data row12 col0" >28</td>
#       <td id="T_99c50_row12_col1" class="data row12 col1" >-0.785714</td>
#       <td id="T_99c50_row12_col2" class="data row12 col2" >企業, 大学, 採用, 企業 就職, 慶応</td>
#     </tr>
#     <tr>
#       <th id="T_99c50_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_99c50_row13_col0" class="data row13 col0" >25</td>
#       <td id="T_99c50_row13_col1" class="data row13 col1" >-0.640000</td>
#       <td id="T_99c50_row13_col2" class="data row13 col2" >職, 学生, 都庁, 大学, 企業</td>
#     </tr>
#     <tr>
#       <th id="T_99c50_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_99c50_row14_col0" class="data row14 col0" >31</td>
#       <td id="T_99c50_row14_col1" class="data row14 col1" >0.032258</td>
#       <td id="T_99c50_row14_col2" class="data row14 col2" >大学, 企業, march, アオヤマ, 早慶</td>
#     </tr>
#     <tr>
#       <th id="T_99c50_level0_row15" class="row
